# %% [markdown]
# <a href="https://colab.research.google.com/github/vandrasmb/StrukturData/blob/main/Pertemuan4_Struktur_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
queue = []

queue.append('a')
queue.append('i')
queue.append('u')
queue.append('e')
queue.append('0')

print('Initial queue')
print(queue)

print('\nElements dequeue from queue:')
print(queue.pop(0))
print(queue.pop(0))
print(queue.pop(0))

print('\nElements dequeued removing elements')
print(queue)
# Out:
# Initial queue
# ['a', 'i', 'u', 'e', '0']
#
# Elements dequeue from queue:
# a
# i
# u
#
# Elements dequeued removing elements
# ['e', '0']

# %%
from collections import deque

queue = deque()

queue.append('a')
queue.append('i')
queue.append('u')
queue.append('e')
queue.append('0')

print('Initial queue')
print(queue)

print('\nElements dequeue from the queue')
print(queue.popleft())
print(queue.popleft())
print(queue.popleft())

print('\nQueue after removing elements')
print(queue)
# Out:
# Initial queue
# deque(['a', 'i', 'u', 'e', '0'])
#
# Elements dequeue from the queue
# a
# i
# u
#
# Queue after removing elements
# deque(['e', '0'])

# %%
from queue import Queue

qu = Queue(maxsize=5)

print(qu.qsize())

qu.put('a')
qu.put('i')
qu.put('u')
qu.put('e')
qu.put('o')

print("Full: ", qu.full())
print("Full: ", qu.qsize())

print('\nElements dequeued from the queue')
print(qu.get())
print(qu.get())
print(qu.get())

print("\nEmpty:", qu.empty())
print("Full:", qu.full())
# Out:
# 0
# Full:  True
# Full:  5
#
# Elements dequeued from the queue
# a
# i
# u
#
# Empty: False
# Full: False

# %%
class Queue:
  def __init__(self):
    self.queue = list()

  def addtoqu(self,dataval):

    if dataval not in self.queue:
      self.queue.insert(0,dataval)
      return True
    return False

  def removefromq(self):
      if len(self.queue)>0:
        return self.queue.pop()
      return ("No elements in queue!")

  def size(self):
      return len(self.queue)

TheQueue = Queue()
print(TheQueue.addtoqu("Jan"))
print(TheQueue.addtoqu("Feb"))
print(TheQueue.addtoqu("March"))
print(TheQueue.addtoqu("April"))
print(TheQueue.size())
print(TheQueue.removefromq())
print(TheQueue.removefromq())
print(TheQueue.size())
# Out:
# True
# True
# True
# True
# 4
# Jan
# Feb
# 2
